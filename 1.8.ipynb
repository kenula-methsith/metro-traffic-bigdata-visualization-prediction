# %%
from pyspark.sql import SparkSession
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# Step 4: Plot Histogram of Traffic Volume
plt.figure(figsize=(8, 5))
sns.histplot(df['traffic_volume'], bins=30, kde=True)  # Correct column name
plt.title("Histogram of Traffic Volume")
plt.xlabel("Traffic Volume")
plt.ylabel("Frequency")
plt.show()

# Step 5: Scatter Plot of Temperature vs Traffic Volume
plt.figure(figsize=(8, 5))
sns.scatterplot(x='temp', y='traffic_volume', data=df)  # Ensure columns exist
plt.title("Scatter Plot of Temperature vs Traffic Volume")
plt.xlabel("Temperature")
plt.ylabel("Traffic Volume")
plt.show()

# Step 6: Stop Spark session
spark.stop()
