# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in c:\users\user\anaconda3\lib\site-packages (3.5.3)
# Requirement already satisfied: py4j==0.10.9.7 in c:\users\user\anaconda3\lib\site-packages (from pyspark) (0.10.9.7)

# %%
from confluent_kafka import Consumer, KafkaError
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
import json

# Kafka Consumer Configuration
consumer_conf = {
    'bootstrap.servers': 'localhost:9092',
    'group.id': 'quotes-consumer',
    'auto.offset.reset': 'earliest'
}
consumer = Consumer(consumer_conf)
topic = 'test-topic'

# Initialize PySpark Session
spark = SparkSession.builder \
    .appName("QuotesConsumer") \
    .getOrCreate()

# List to temporarily hold consumed data
data_list = []

# Function to process each Kafka message
def process_message(message):
    try:
        data = json.loads(message)
        data_list.append((data['id'], data['quote'], data['author'], len(data['quote'])))
    except (json.JSONDecodeError, KeyError):
        print("Error processing message or missing fields")

# Function to consume messages from Kafka and calculate statistics
def consume_messages():
    print("Listening for messages...")
    consumer.subscribe([topic])
    try:
        while True:
            msg = consumer.poll(timeout=1.0)
            if msg is None:
                continue
            if msg.error():
                if msg.error().code() == KafkaError._PARTITION_EOF:
                    print(f"End of partition reached: {msg.topic()} [{msg.partition()}] at offset {msg.offset()}")
                else:
                    print(f"Error: {msg.error()}")
            else:
                print(f"Received message: {msg.value().decode('utf-8')}")
                process_message(msg.value().decode('utf-8'))

    except KeyboardInterrupt:
        print("\nConsumer interrupted. Shutting down...")

        if data_list:
            # Load data into a PySpark DataFrame
            df = spark.createDataFrame(data_list, ["id", "quote", "author", "quote_length"])
            df.show(truncate=False)

            # Descriptive Statistics for Numeric Fields
            print("\nDescriptive Statistics (Numeric):")
            df.describe("id", "quote_length").show()

            # Count of Unique Authors
            unique_authors = df.select("author").distinct().count()
            print(f"\nNumber of unique authors: {unique_authors}")

            # Aggregate Metrics (Average and Standard Deviation of Quote Length)
            print("\nAggregate Metrics:")
            df.agg(
                F.avg("quote_length").alias("avg_quote_length"),
                F.stddev("quote_length").alias("stddev_quote_length")
            ).show()
        else:
            print("No data to analyze.")

    finally:
        consumer.close()
        print("Consumer closed.")

consume_messages()
# Out:
# Listening for messages...
# Received message: Hello Kafka!
# Error processing message or missing fields
# Received message:
# Error processing message or missing fields
# Received message: Hellow
# Error processing message or missing fields
# Received message: addoow
# Error processing message or missing fields
# Received message: yoooooooo
# Error processing message or missing fields
# Received message: Test Message 0
# Error processing message or missing fields
# Received message: Test Message 1
# Error processing message or missing fields
# Received message: Test Message 2
# Error processing message or missing fields
# Received message: Test Message 3
# Error processing message or missing fields
# Received message: Test Message 4
# Error processing message or missing fields
# Received message: Test Message 0
# Error processing message or missing fields
# Received message: Test Message 1
# Error processing message or missing fields
# Received message: Test Message 2
# Error processing message or missing fields
# Received message: Test Message 3
# Error processing message or missing fields
# Received message: Test Message 4
# Error processing message or missing fields
# Received message: {"id": 429, "quote": "It Is From Books That Wise People Derive Consolation In The Troubles Of Life.", "author": "Victor Hugo"}
# Received message: {"id": 681, "quote": "A Man Should Never Neglect His Family For Business.", "author": "Walt Disney"}
# Received message: {"id": 1422, "quote": "Coming Together Is A Beginning; Keeping Together Is Progress; Working Together Is Success.", "author": "Henry Ford"}
# Received message: {"id": 774, "quote": "You have to dream before your dreams can come true.", "author": "Abdul Kalam"}
# Received message: {"id": 1451, "quote": "Positive Thinking Will Let You Do Everything Better Than Negative Thinking Will.", "author": "Zig Ziglar"}
# Received message: {"id": 1401, "quote": "Those who cannot work with their hearts achieve but a hollow, half-hearted success that breeds bitterness all around.", "author": "Abdul Kalam"}
# Received message: {"id": 269, "quote": "As To The Mental Essence, We Find It In Infants Devoid Of Every Mental Form.", "author": "Avicenna"}
# Received message: {"id": 521, "quote": "Ah, Mon Cher, For Anyone Who Is Alone, Without God And Without A Master, The Weight Of Days Is Dreadful.", "author": "Albert Camus"}
# Received message: {"id": 820, "quote": "Failure Is A Detour, Not A Dead-End Street.", "author": "Zig Ziglar"}
# Received message: {"id": 1407, "quote": "To be a great champion you must believe you are the best. If you're not, pretend you are.", "author": "Muhammad Ali"}
# Received message: {"id": 855, "quote": "Let Us Not Be Too Particular; It Is Better To Have Old Secondhand Diamonds Than None At All.", "author": "Mark Twain"}
# Received message: {"id": 1445, "quote": "To forgive an oppressor is oppression upon the oppressed.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 1301, "quote": "I'm so mean I make medicine sick!", "author": "Muhammad Ali"}
# Received message: {"id": 1131, "quote": "Expect The Best. Prepare For The Worst. Capitalize On What Comes.", "author": "Zig Ziglar"}
# Received message: {"id": 545, "quote": "O World, try to deceive someone else. Are you trying to tempt me or attract me? No way! I divorce you irrevocably. Your time is short and you are insignificant. Alas! The provision is little, the journey is long and the way is lonely.", "author": "Ali ibn Abi Talib (R.A)"}
# Received message: {"id": 1211, "quote": "We are a people whom Allah gave might and glory to through Islam, so we will never seek glory through anything else.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 461, "quote": "To make one good action succeed another, is the perfection of goodness.", "author": "Ali ibn Abi Talib (R.A)"}
# Received message: {"id": 139, "quote": "The Difference Between A Mountain And A Molehill Is Your Perspective.", "author": "Al Neuharth"}
# Received message: {"id": 1356, "quote": "We Have New Developing Ties With Japan Whom Always Supports Our Democratic Process And Economic Development.", "author": "Ali A. Saleh"}
# Received message: {"id": 1382, "quote": "Here is a relationship booster that is guaranteed to work: Every time your spouse or lover says something stupid make your eyes light up as if you just heard something brilliant.", "author": "Rumi"}
# Received message: {"id": 143, "quote": "Be patient; patience is a pillar of faith.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 110, "quote": "Love Is Blind; Friendship Closes Its Eyes.", "author": "Friedrich Nietzsche"}
# Received message: {"id": 1450, "quote": "The breeze at dawn has secrets to tell you. Don't go back to sleep.", "author": "Rumi"}
# Received message: {"id": 869, "quote": "Put yourself out on a limb, sucka, like me!", "author": "Muhammad Ali"}
# Received message: {"id": 564, "quote": "The one from among the Muslims who recites the Qur'an but in the end finds his way to hell, is considered to be among those that have taken the word of Allah in jest.", "author": "Ali ibn Abi Talib (R.A)"}
# Received message: {"id": 685, "quote": "Sell your cleverness and buy bewilderment.", "author": "Rumi"}
# Received message: {"id": 226, "quote": "Love Is The Only Force Capable Of Transforming An Enemy Into Friend.", "author": "Martin Luther King  Jr."}
# Received message: {"id": 157, "quote": "When I Do Good, I Feel Good. When I Do Bad, I Feel Bad. That'S My Religion.", "author": "Abraham Lincoln"}
# Received message: {"id": 1272, "quote": "He who wins through fraud is not a winner.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 81, "quote": "We Enjoy The Process Far More Than The Proceeds.", "author": "Warren Buffett"}
# Received message: {"id": 1208, "quote": "Muslims Should Live Like Brothers.", "author": "Abu Bakr"}
# Received message: {"id": 1446, "quote": "Our death is our wedding with eternity.", "author": "Rumi"}
# Received message: {"id": 89, "quote": "It Is Easier To Stay Out Than Get Out.", "author": "Mark Twain"}
# Received message: {"id": 688, "quote": "Kindness Is The Language Which The Deaf Can Hear And The Blind Can See.", "author": "Mark Twain"}
# Received message: {"id": 173, "quote": "Change Your Opinions, Keep To Your Principles; Change Your Leaves, Keep Intact Your Roots.", "author": "Victor Hugo"}
# Received message: {"id": 616, "quote": "Keep Your Eyes Wide Open Before Marriage, Half Shut Afterwards.", "author": "Benjamin Franklin"}
# Received message: {"id": 1404, "quote": "That's okay, I'm still the Greatest.", "author": "Muhammad Ali"}
# Received message: {"id": 1102, "quote": "I'm too fast. I'm too smart. I'm too pretty.", "author": "Muhammad Ali"}
# Received message: {"id": 252, "quote": "Life Loves The Liver Of It.", "author": "Maya Angelou"}
# Received message: {"id": 455, "quote": "Do not be too hard, lest you be broken; do not be too soft, lest you be squeezed.", "author": "Ali ibn Abi Talib (R.A)"}
# Received message: {"id": 727, "quote": "Joy In Looking And Comprehending Is Nature'S Most Beautiful Gift.", "author": "Albert Einstein"}
# Received message: {"id": 65, "quote": "It's not bragging if you can back it up.", "author": "Muhammad Ali"}
# Received message: {"id": 1125, "quote": "The Educated Southerner Has No Use For An 'R', Except At The Beginning Of A Word.", "author": "Mark Twain"}
# Received message: {"id": 753, "quote": "If you want to control other people, first control yourself.", "author": "Abu Bakr (R.A)"}
# Received message: {"id": 484, "quote": "Your worst enemy is hiding within yourself, and that enemy is your nafs or false ego.", "author": "Rumi"}
# Received message: {"id": 134, "quote": "Don't count the days, make the days count.", "author": "Muhammad Ali"}
# Received message: {"id": 347, "quote": "If I Were Not A Physicist, I Would Probably Be A Musician. I Often Think In Music. I Live My Daydreams In Music. I See My Life In Terms Of Music.", "author": "Albert Einstein"}
# Received message: {"id": 717, "quote": "Inside you there's an artist you don't know about.", "author": "Rumi"}
# Received message: {"id": 1390, "quote": "Wherever you stand, be the soul of that place.", "author": "Rumi"}
# Received message: {"id": 828, "quote": "The Educated Differ From The Uneducated As Much As The Living From The Dead.", "author": "Aristotle"}
# Received message: {"id": 793, "quote": "Achieving Life Is Not The Equivalent Of Avoiding Death.", "author": "Ayn Rand"}
# Received message: {"id": 546, "quote": "There are so many highly esteemed ones who became miserable and humiliated just because of their bad temper and morals; and humble people who have attained eminence and the highest honors because of good temper and morals.", "author": "Ali ibn Abi Talib (R.A)"}
# Received message: {"id": 123, "quote": "Good Actions Are A Guard Against The Blows Of Adversity.", "author": "Abu Bakr"}
# Received message: {"id": 1205, "quote": "Fear Allah, for that is fortune; indifference to Allah is misfortune.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 912, "quote": "My Mission In Life Is Not Merely To Survive, But To Thrive; And To Do So With Some Passion, Some Compassion, Some Humor, And Some Style", "author": "Maya Angelou"}
# Received message: {"id": 560, "quote": "Patience is the healthiest ingredient of our life.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 1312, "quote": "A Thorough Knowledge Of The Bible Is Worth More Than A College Education.", "author": "Theodore Roosevelt"}
# Received message: {"id": 896, "quote": "Shine like the whole universe is yours.", "author": "Rumi"}
# Received message: {"id": 412, "quote": "You Are Not Only Responsible For What You Say, But Also For What You Do Not Say.", "author": "Martin Luther"}
# Received message: {"id": 694, "quote": "Be Happy In The Moment, That'S Enough. Each Moment Is All We Need, Not More.", "author": "Mother Teresa"}
# Received message: {"id": 365, "quote": "Don'T Be Distracted By Criticism. Remember ~ The Only Taste Of Success Some People Have Is When They Take A Bite Out Of You.", "author": "Zig Ziglar"}
# Received message: {"id": 1161, "quote": "I Believe In Christianity As I Believe That The Sun Has Risen: Not Only Because I See It, But Because By It I See Everything Else.", "author": "C. S. Lewis"}
# Received message: {"id": 558, "quote": "The government, whether state or central, is elected. That means we have a responsibility to elect the right kind of leaders.", "author": "Abdul Kalam"}
# Received message: {"id": 257, "quote": "This life is not real. I conquered the world and it did not bring me satisfaction.", "author": "Muhammad Ali"}
# Received message: {"id": 1436, "quote": "All Credibility, All Good Conscience, All Evidence Of Truth Come Only From The Senses.", "author": "Friedrich Nietzsche"}
# Received message: {"id": 1335, "quote": "Being Ignorant Is Not So Much A Shame, As Being Unwilling To Learn.", "author": "Benjamin Franklin"}
# Received message: {"id": 86, "quote": "Never Allow Someone To Be Your Priority While Allowing Yourself To Be Their Option.", "author": "Mark Twain"}
# Received message: {"id": 1331, "quote": "To Love is to reach God.", "author": "Rumi"}
# Received message: {"id": 191, "quote": "The best way to make your dreams come true is to wake up.", "author": "Muhammad Ali"}
# Received message: {"id": 204, "quote": "Hold on to your Salah, because if you lose that, you will lose everything else.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 1385, "quote": "Learning gives creativity. Creativity leads to thinking. Thinking provides knowledge. Knowledge makes you great.", "author": "Abdul Kalam"}
# Received message: {"id": 802, "quote": "Divine Life Is In Touch With The Whole Universe On The Analogy Of The Soul'S Contact With The Body.", "author": "Muhammed Iqbal"}
# Received message: {"id": 785, "quote": "Cursed Is The Man Who Dies, But The Evil Done By Him Survives.", "author": "Abu Bakr"}
# Received message: {"id": 1159, "quote": "Do You Think God Gets Stoned? I Think So... Look At The Platypus.", "author": "Robin Williams"}
# Received message: {"id": 1087, "quote": "I am the greatest, I said that even before I knew I was.", "author": "Muhammad Ali"}
# Received message: {"id": 832, "quote": "Let'S Pray That The Human Race Never Escapes From Earth To Spread Its Iniquity Elsewhere.", "author": "C. S. Lewis"}
# Received message: {"id": 128, "quote": "This Is The First Convention Of The Space Age - Where A Candidate Can Promise The Moon And Mean It.", "author": "David Brinkley"}
# Received message: {"id": 688, "quote": "Kindness Is The Language Which The Deaf Can Hear And The Blind Can See.", "author": "Mark Twain"}
# Received message: {"id": 1216, "quote": "Russia Is A Riddle Wrapped In A Mystery Inside An Enigma.", "author": "Winston Churchill"}
# Received message: {"id": 822, "quote": "Body is purified by water. Ego by tears. Intellect is purified by knowledge. And soul is purified with love.", "author": "Ali ibn Abi Talib (R.A)"}
# Received message: {"id": 322, "quote": "When a man puts me a question, I judge of his intelligence.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 342, "quote": "Even If I Knew That Tomorrow The World Would Go To Pieces, I Would Still Plant My Apple Tree.", "author": "Martin Luther"}
# Received message: {"id": 1047, "quote": "Gratitude is the wine for the soul. Go on. Get drunk.", "author": "Rumi"}
# Received message: {"id": 468, "quote": "The Will To Win, The Desire To Succeed, The Urge To Reach Your Full Potential... These Are The Keys That Will Unlock The Door To Personal Excellence.", "author": "Confucius"}
# Received message: {"id": 638, "quote": "Be melting snow. Wash yourself of yourself.", "author": "Rumi"}
# Received message: {"id": 67, "quote": "Why do I want my wife to show off her panties when the wind blows? Horses show their behinds, and cows and mules, not humans.", "author": "Muhammad Ali"}
# Received message: {"id": 924, "quote": "Just Go Up To Somebody On The Street And Say \"You'Re It!\" And Then Run Away.", "author": "Ellen DeGeneres"}
# Received message: {"id": 998, "quote": "Like your body your mind also gets tired so refresh it by wise sayings.", "author": "Ali ibn Abi Talib (R.A)"}
# Received message: {"id": 526, "quote": "What keeps me going is goals.", "author": "Muhammad Ali"}
# Received message: {"id": 711, "quote": "My Father Always Told Me That All Businessmen Were Sons Of Bitches, But I Never Believed It Till Now.", "author": "John F. Kennedy"}
# Received message: {"id": 23, "quote": "God Doesn'T Require Us To Succeed, He Only Requires That You Try.", "author": "Mother Teresa"}
# Received message: {"id": 874, "quote": "I Have Tried Lately To Read Shakespeare, And Found It So Intolerably Dull That It Nauseated Me.", "author": "Charles Darwin"}
# Received message: {"id": 590, "quote": "A man may be as straight as an arrow, but even then he will have some critics.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 14, "quote": "If you even dream of beating me you'd better wake up and apologize.", "author": "Muhammad Ali"}
# Received message: {"id": 1216, "quote": "Russia Is A Riddle Wrapped In A Mystery Inside An Enigma.", "author": "Winston Churchill"}
# Received message: {"id": 957, "quote": "I Feel The Same Way About Disco As I Do About Herpes.", "author": "Hunter S. Thompson"}
# Received message: {"id": 663, "quote": "Never Mistake Motion For Action.", "author": "Ernest Hemingway"}
# Received message: {"id": 36, "quote": "I'm not a handsome guy, but I can give my hand to someone who needs help. Beauty is in the heart, not in the face.", "author": "Abdul Kalam"}
# Received message: {"id": 757, "quote": "I Will Carry On Writing, To Be Sure. But I Don'T Know If I Would Want To Publish Again After Harry Potter.", "author": "J. K. Rowling"}
# Received message: {"id": 1120, "quote": "Talent In Cheaper Than Table Salt. What Separates The Talented Individual From The Successful One Is A Lot Of Hard Work.", "author": "Stephen King"}
# Received message: {"id": 1295, "quote": "You Cannot Escape The Responsibility Of Tomorrow By Evading It Today.", "author": "Abraham Lincoln"}
# Received message: {"id": 473, "quote": "A Question That Sometimes Drives Me Hazy: Am I Or Are The Others Crazy?", "author": "Albert Einstein"}
# Received message: {"id": 1280, "quote": "Loyalty To The Country Always. Loyalty To The Government When It Deserves It.", "author": "Mark Twain"}
# Received message: {"id": 325, "quote": "The criterion of action is that todays work should not be deferred till the following day.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 372, "quote": "I know where I'm going and I know the truth, and I don't have to be what you want me to be. I'm free to be what I want.", "author": "Muhammad Ali"}
# Received message: {"id": 501, "quote": "God gave me Parkinson's syndrome to show me I'm not 'The Greatest' - he is.", "author": "Muhammad Ali"}
# Received message: {"id": 517, "quote": "Dream, Dream Dream Dreams transform into thoughts And thoughts result in action.", "author": "Abdul Kalam"}
# Received message: {"id": 1382, "quote": "Here is a relationship booster that is guaranteed to work: Every time your spouse or lover says something stupid make your eyes light up as if you just heard something brilliant.", "author": "Rumi"}
# Received message: {"id": 437, "quote": "A heart filled with love is like a phoenix that no cage can imprison.", "author": "Rumi"}
# Received message: {"id": 631, "quote": "I say get an education. Become an electrician, a mechanic, a doctor, a lawyer, anything but a fighter. In this trade, it's the managers that make the money and last the longest.", "author": "Muhammad Ali"}
# Received message: {"id": 899, "quote": "Lovely days don't come to you, you should walk to them.", "author": "Rumi"}
# Received message: {"id": 1038, "quote": "I'm going to show you how great I am!", "author": "Muhammad Ali"}
# Received message: {"id": 1374, "quote": "Seek the wisdom that will untie your knot. Seek the path that demands your whole being.", "author": "Rumi"}
# Received message: {"id": 1149, "quote": "O Allah do not give me in excess lest I may be disobedient.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 715, "quote": "Be good to others, that will protect you against evil.", "author": "Abu Bakr (R.A)"}
# Received message: {"id": 175, "quote": "Strong And Bitter Words Indicate A Weak Cause.", "author": "Victor Hugo"}
# Received message: {"id": 140, "quote": "I Am Certainly Not One Of Those Who Need To Be Prodded. In Fact, If Anything, I Am The Prod.", "author": "Winston Churchill"}
# Received message: {"id": 209, "quote": "Greed is permanent slavery.", "author": "Ali ibn Abi Talib (R.A)"}
# Received message: {"id": 182, "quote": "A Riot Is The Language Of The Unheard.", "author": "Martin Luther King, Jr."}
# Received message: {"id": 910, "quote": "Everyone Should Be Respected As An Individual, But No One Idolized.", "author": "Albert Einstein"}
# Received message: {"id": 393, "quote": "All My Life Through, The New Sights Of Nature Made Me Rejoice Like A Child.", "author": "Marie Curie"}
# Received message: {"id": 482, "quote": "Thinking should become your capital asset, no matter whatever ups and downs you come across in your life.", "author": "Abdul Kalam"}
# Received message: {"id": 195, "quote": "No amount of guilt can change the past and no amount of worrying can change the future.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 1120, "quote": "Talent In Cheaper Than Table Salt. What Separates The Talented Individual From The Successful One Is A Lot Of Hard Work.", "author": "Stephen King"}
# Received message: {"id": 754, "quote": "Patience is of two kinds: patience over what pains you, and patience against what you covet.", "author": "Ali ibn Abi Talib (R.A)"}
# Received message: {"id": 552, "quote": "Give Me Six Hours To Chop Down A Tree And I Will Spend The First Four Sharpening The Axe.", "author": "Abraham Lincoln"}
# Received message: {"id": 430, "quote": "Take Things As They Are. Punch When You Have To Punch. Kick When You Have To Kick.", "author": "Bruce Lee"}
# Received message: {"id": 110, "quote": "Love Is Blind; Friendship Closes Its Eyes.", "author": "Friedrich Nietzsche"}
# Received message: {"id": 1418, "quote": "It Is Not Best That We Should All Think Alike; It Is A Difference Of Opinion That Makes Horse Races.", "author": "Mark Twain"}
# Received message: {"id": 342, "quote": "Even If I Knew That Tomorrow The World Would Go To Pieces, I Would Still Plant My Apple Tree.", "author": "Martin Luther"}
# Received message: {"id": 50, "quote": "Sometimes the people with the worst past, create the best future.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 1192, "quote": "We Are Not Trying To Entertain The Critics. I'Ll Take My Chances With The Public.", "author": "Walt Disney"}
# Received message: {"id": 767, "quote": "Out beyond ideas of wrongdoing and rightdoing there is a field. I'll meet you there. When the soul lies down in that grass the world is too full to talk about.", "author": "Rumi"}
# Received message: {"id": 1061, "quote": "I am grateful for all my victories, but I am especially grateful for my losses, because they only made me work harder.", "author": "Muhammad Ali"}
# Received message: {"id": 1342, "quote": "He Who Angers You Conquers You.", "author": "Elizabeth Kenny"}
# Received message: {"id": 1357, "quote": "George Washington, As A Boy, Was Ignorant Of The Commonest Accomplishments Of Youth. He Could Not Even Lie.", "author": "Mark Twain"}
# Received message: {"id": 508, "quote": "Often your utterances and expressions of your face leak out the secrets of your hidden thoughts.", "author": "Ali ibn Abi Talib (R.A)"}
# Received message: {"id": 381, "quote": "If you wish to be a mine of jewels, open the deep ocean within your heart.", "author": "Rumi"}
# Received message: {"id": 390, "quote": "My Religion Is Very Simple. My Religion Is Kindness.", "author": "Dalai Lama"}
# Received message: {"id": 1028, "quote": "I Never Think Of The Future - It Comes Soon Enough.", "author": "Albert Einstein"}
# Received message: {"id": 1049, "quote": "The days of life pass away like clouds, so do good while you are alive.", "author": "Ali ibn Abi Talib (R.A)"}
# Received message: {"id": 559, "quote": "Lead such a life, that, when you die, the people may mourn you, and while you are alive they long for your company.", "author": "Ali ibn Abi Talib (R.A)"}
# Received message: {"id": 1365, "quote": "My view is that at a younger age your optimism is more and you have more imagination etc. You have less bias.", "author": "Abdul Kalam"}
# Received message: {"id": 1222, "quote": "Opportunity Is Missed By Most People Because It Is Dressed In Overalls And Looks Like Work.", "author": "Thomas A. Edison"}
# Received message: {"id": 819, "quote": "Great dreams of great dreamers are always transcended.", "author": "Abdul Kalam"}
# Received message: {"id": 1394, "quote": "Men And Women Belong To Different Species And Communications Between Them Is Still In Its Infancy.", "author": "Bill Cosby"}
# Received message: {"id": 601, "quote": "Live everyday as if it were your last because someday you're going to be right.", "author": "Muhammad Ali"}
# Received message: {"id": 199, "quote": "Cursed is the man who dies, but the evil done by him survives.", "author": "Abu Bakr (R.A)"}
# Received message: {"id": 290, "quote": "Your longing for ME is my message to you, All your attempts to reach ME, Are in reality MY attempts to reach you.", "author": "Rumi"}
# Received message: {"id": 246, "quote": "A Compliment Is Something Like A Kiss Through A Veil.", "author": "Victor Hugo"}
# Received message: {"id": 670, "quote": "To speak less is wisdom, to eat less is healthy, and to mingle less with te people is safe and serene.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 493, "quote": "I searched for God and found only myself. I searched for myself and found only God.", "author": "Rumi"}
# Received message: {"id": 104, "quote": "For 2,500 years, India has never invaded anybody.", "author": "Abdul Kalam"}
# Received message: {"id": 255, "quote": "There is a way between voice and presence, where information flows. In disciplined silence it opens; with wandering talk it closes.", "author": "Rumi"}
# Received message: {"id": 1142, "quote": "To be alone means that you avoid bad company. But to have a true friend is better than being alone.", "author": "Umar ibn Al-Khatt\u0101b (R.A)"}
# Received message: {"id": 390, "quote": "My Religion Is Very Simple. My Religion Is Kindness.", "author": "Dalai Lama"}
# Received message: {"id": 46, "quote": "Applause Waits On Success.", "author": "Benjamin Franklin"}
# Received message: {"id": 1423, "quote": "Total commitment is the common denominator among all successful men and women.", "author": "Abdul Kalam"}
# Received message: {"id": 206, "quote": "Be Faithful In Small Things Because It Is In Them That Your Strength Lies.", "author": "Mother Teresa"}
# Received message: {"id": 688, "quote": "Kindness Is The Language Which The Deaf Can Hear And The Blind Can See.", "author": "Mark Twain"}
# Received message: {"id": 266, "quote": "I Feel Much Freer Now That I Am Certain The Pope Is The Antichrist.", "author": "Martin Luther"}
